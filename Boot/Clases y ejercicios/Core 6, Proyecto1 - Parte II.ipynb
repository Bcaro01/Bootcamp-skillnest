# %% [markdown]
# ### Librerías y entorno

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Carga de los datos

# %%
# Carga y procesamiento de datos
path = 'C:/Users/Bcaro/OneDrive/Documentos/VSC/Skillnest/Boot/Clases y ejercicios/Excels - Datos/retail_sales_dataset.csv'
df = pd.read_csv(path)
df.head(10)
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
# 5               6  2023-04-25     CUST006  Female   45           Beauty
# 6               7  2023-03-13     CUST007    Male   46         Clothing
# 7               8  2023-02-22     CUST008    Male   30      Electronics
# 8               9  2023-12-13     CUST009    Male   63      Electronics
# 9              10  2023-10-07     CUST010  Female   52         Clothing
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# ...

# %% [markdown]
# ### EDA

# %%
df.tail()
df.info() # todos los datos estan bien
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# ...

# %% [markdown]
# ### Inspección de datos

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %%
df['Product Category'].value_counts() # se asume que la instrucción hace referencia al dato "Product Category" cuando menciona la columna "Producto"
# Out:
# Clothing       351
# Electronics    342
# Beauty         307
# Name: Product Category, dtype: int64

# %%
# considerando que en el data set no existe la columna "tienda" o "stores" ni nada similar, se filtra por el género de los clientes.
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ### Filtrado de datos

# %%
# se filtra para obtener las ventas mayores a 50
# Se asume que las "Ventas" hacen referencia al dato "Total Amount", ya que tambien se podría asumir que se refiere al hecho de la venta o a la cantidad de unidades vendidas.

df[df['Total Amount'] > 50]
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# 7                 8  2023-02-22     CUST008    Male   30      Electronics
# ..              ...         ...         ...     ...  ...              ...
# 993             994  2023-12-18     CUST994  Female   51           Beauty
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
# se filtra para obtener las precio menor a 0.5
# Se asume que las "Precio" hacen referencia al dato "Price per Unit"
# Como no existe ningun valor menor que 0.5, se filtra por montos menores a 30 unidaes monetarias

df[df['Price per Unit'] < 30]
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 6                 7  2023-03-13     CUST007    Male   46         Clothing
# 7                 8  2023-02-22     CUST008    Male   30      Electronics
# 11               12  2023-10-30     CUST012    Male   35           Beauty
# 16               17  2023-04-22     CUST017  Female   27         Clothing
# 17               18  2023-04-30     CUST018  Female   47      Electronics
# ..              ...         ...         ...     ...  ...              ...
# 979             980  2023-07-29     CUST980  Female   31      Electronics
# 984             985  2023-05-30     CUST985  Female   19      Electronics
# 987             988  2023-05-28     CUST988  Female   63         Clothing
# 988             989  2023-12-28     CUST989  Female   44      Electronics
# 997             998  2023-10-29     CUST998  Female   23           Beauty
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
# Debido a que en el enunciado se solicita filtar por productos de tipo "Manzana" con ventas mayores a 30 UM (Unidades Monetarias), y esto no existe,
# Se filtrará por productos de tipo "Clothing" en donde sus ventas sean mayores	30. con el mismo supuesto de que las ventas se refiere al Total Amount.

filtered_df = df.query('(`Product Category` == "Clothing") & (`Total Amount` >= 30)')
filtered_df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 6                 7  2023-03-13     CUST007    Male   46         Clothing
# 9                10  2023-10-07     CUST010  Female   52         Clothing
# 10               11  2023-02-14     CUST011    Male   23         Clothing
# ..              ...         ...         ...     ...  ...              ...
# 986             987  2023-04-29     CUST987  Female   30         Clothing
# 987             988  2023-05-28     CUST988  Female   63         Clothing
# 990             991  2023-12-26     CUST991  Female   34         Clothing
# 994             995  2023-04-30     CUST995  Female   41         Clothing
# 995             996  2023-05-16     CUST996    Male   62         Clothing
#
#      Quantity  Price per Unit  Total Amount
# ...

# %% [markdown]
# ### Slicing de datos

# %%
# una vez mas, se asume que "productos" se refiere a "Product Category" y "ventas" a "Total Amount"

df[['Product Category', 'Total Amount']]
# Out:
#     Product Category  Total Amount
# 0             Beauty           150
# 1           Clothing          1000
# 2        Electronics            30
# 3           Clothing           500
# 4             Beauty           100
# ..               ...           ...
# 995         Clothing            50
# 996           Beauty            90
# 997           Beauty           100
# 998      Electronics           150
# 999      Electronics           120
#
# [1000 rows x 2 columns]

# %%
# Debido a que no existe el dato "Tienda", se reemplazará por el dato existente "Gender"

df.loc[5:10, ['Product Category', 'Gender']]
# Out:
#    Product Category  Gender
# 5            Beauty  Female
# 6          Clothing    Male
# 7       Electronics    Male
# 8       Electronics    Male
# 9          Clothing  Female
# 10         Clothing    Male

# %%
df.iloc[:5, :3]
# Out:
#    Transaction ID        Date Customer ID
# 0               1  2023-11-24     CUST001
# 1               2  2023-02-27     CUST002
# 2               3  2023-01-13     CUST003
# 3               4  2023-05-21     CUST004
# 4               5  2023-05-06     CUST005
